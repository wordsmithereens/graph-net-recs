# %% [markdown]
# ### Workflow & Task
# * Calculate the centrality measures for each node.
# * Add the centrality measures to the node list and convert it into a dataframe (assign to each node).
# * Select an individual chapter, calculate all nodes connected to this node, and convert into a dataframe (make sure there are at least 2 connections).
# * Combine the dataframes into a new dataframe that contains the connected nodes and their centrality measures.
# * Sort by one of the centrality measures to create a basic recommendation.

# %%
from collections import Counter
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from networkx.algorithms.centrality import betweenness_centrality

# %%
df = pd.read_csv('edges.csv', sep='\t')
df
# Out:
#          user_id  number_of_ticks         date_created     chapter  \
# 0    -2146355313                8  2019-12-14 10:05:50   chapter-1
# 1    -2146355313                8  2019-12-14 10:05:50   chapter-1
# 2    -2145886989               10  2019-12-10 13:41:25   chapter-4
# 3    -2145886989                1  2019-12-10 19:37:20   chapter-1
# 4    -2145886989                5  2019-12-10 19:37:50   chapter-1
# ...          ...              ...                  ...         ...
# 4353 -2019295583               10  2019-12-07 16:09:21   chapter-1
# 4354 -2019295583              102  2019-12-07 16:14:21   chapter-1
# 4355 -2019295583              107  2019-12-07 17:51:22   chapter-1
# 4356 -2019295583               98  2019-12-07 20:54:58   chapter-1
# 4357 -2019295583               15  2019-12-07 22:02:29   chapter-1
#
#              book  numberofentriesofbook  numberofusersofbook  \
# 0      ramamurthy                    715                  202
# 1          thomas                    445                  136
# 2        mcnamara                   2533                  461
# 3        mcnamara                   2533                  461
# 4        mcnamara                   2533                  461
# ...           ...                    ...                  ...
# 4353  roestenburg                    344                   65
# 4354  roestenburg                    344                   65
# 4355  roestenburg                    344                   65
# 4356  roestenburg                    344                   65
# 4357  roestenburg                    344                   65
#
#       product_manning_id  user_owns_book                        book_ch  \
# 0                   1120               1    ('ramamurthy', 'chapter-1')
# 1                    816               1        ('thomas', 'chapter-1')
# 2                    880               1      ('mcnamara', 'chapter-4')
# 3                    880               1      ('mcnamara', 'chapter-1')
# 4                    880               1      ('mcnamara', 'chapter-1')
# ...                  ...             ...                            ...
# 4353                 486               0  ('roestenburg', ' chapter-1')
# 4354                 486               0  ('roestenburg', ' chapter-1')
# 4355                 486               0  ('roestenburg', ' chapter-1')
# 4356                 486               0  ('roestenburg', ' chapter-1')
# 4357                 486               0  ('roestenburg', ' chapter-1')
#
#                              source                         target
# 0            ('fain3', 'chapter-8')    ('ramamurthy', 'chapter-1')
# 1       ('ramamurthy', 'chapter-1')        ('thomas', 'chapter-1')
# 2         ('mcnamara', 'chapter-4')      ('mcnamara', 'chapter-4')
# 3         ('mcnamara', 'chapter-4')      ('mcnamara', 'chapter-1')
# 4         ('mcnamara', 'chapter-1')      ('mcnamara', 'chapter-1')
# ...                             ...                            ...
# 4353  ('roestenburg', ' chapter-1')  ('roestenburg', ' chapter-1')
# 4354  ('roestenburg', ' chapter-1')  ('roestenburg', ' chapter-1')
# 4355  ('roestenburg', ' chapter-1')  ('roestenburg', ' chapter-1')
# 4356  ('roestenburg', ' chapter-1')  ('roestenburg', ' chapter-1')
# 4357  ('roestenburg', ' chapter-1')  ('roestenburg', ' chapter-1')
#
# [4358 rows x 12 columns]

# %%
sources, targets = df['source'].tolist(), df['target'].tolist()
edges = list(zip(sources, targets))

df['source_centrality'] = [centrality[tmp] for tmp in df['source']]
df['target_centrality'] = [centrality[tmp] for tmp in df['target']]
df.head()
# Out:
#       user_id  number_of_ticks         date_created    chapter        book  \
# 0 -2146355313                8  2019-12-14 10:05:50  chapter-1  ramamurthy
# 1 -2146355313                8  2019-12-14 10:05:50  chapter-1      thomas
# 2 -2145886989               10  2019-12-10 13:41:25  chapter-4    mcnamara
# 3 -2145886989                1  2019-12-10 19:37:20  chapter-1    mcnamara
# 4 -2145886989                5  2019-12-10 19:37:50  chapter-1    mcnamara
#
#    numberofentriesofbook  numberofusersofbook  product_manning_id  \
# 0                    715                  202                1120
# 1                    445                  136                 816
# 2                   2533                  461                 880
# 3                   2533                  461                 880
# 4                   2533                  461                 880
#
#    user_owns_book                      book_ch                       source  \
# 0               1  ('ramamurthy', 'chapter-1')       ('fain3', 'chapter-8')
# 1               1      ('thomas', 'chapter-1')  ('ramamurthy', 'chapter-1')
# 2               1    ('mcnamara', 'chapter-4')    ('mcnamara', 'chapter-4')
# 3               1    ('mcnamara', 'chapter-1')    ('mcnamara', 'chapter-4')
# 4               1    ('mcnamara', 'chapter-1')    ('mcnamara', 'chapter-1')
#
#                         target  source_centrality  target_centrality
# 0  ('ramamurthy', 'chapter-1')       0.000000e+00       5.091126e-07
# 1      ('thomas', 'chapter-1')       5.091126e-07       0.000000e+00
# 2    ('mcnamara', 'chapter-4')       1.095101e-03       1.095101e-03
# 3    ('mcnamara', 'chapter-1')       1.095101e-03       1.540575e-03
# 4    ('mcnamara', 'chapter-1')       1.540575e-03       1.540575e-03

# %% [markdown]
# # Find the top 10 chapters/books people start with

# %%
cnt = Counter()
seen = set()
for idx, row in df.iterrows():
    if row['user_id'] not in seen:
        cnt.update({row['source'] : 1})
        seen.add(row['user_id'])
cnt.most_common(10)
# Out:
# [("('windmill', ' chapter-2')", 6),
#  ("('lauret', ' about-this-book')", 4),
#  ("('richardson3', ' about-this-book')", 4),
#  ("('windmill', ' chapter-1')", 4),
#  ("('davis4', ' welcome')", 4),
#  ("('jain', ' chapter-1')", 4),
#  ("('windmill', ' welcome')", 3),
#  ("('love', ' welcome')", 3),
#  ("('mcnamara', ' welcome')", 3),
#  ("('gustedt', ' chapter-1')", 3)]

# %% [markdown]
# # Choose the most common book

# %%
def edge_to_book(edge_str):
    """
    >>> edge_to_book("('windmill', ' chapter-2')")
    'windmill'
    """
    return edge_str.split("', '")[0].replace("('", "")

chosen_book = edge_to_book(cnt.most_common(10)[1][0])  

chosen_book
# Out:
# 'lauret'

# %% [markdown]
# ## Task
# * Find the most common book people start with
# * Find which books they most commonly transition to
# * sort by centrality and use that as a recommendation

# %%
results=[]
cnt =Counter()
for idx, row in df.iterrows():
    source_book = edge_to_book(row['source'])
    target_book = edge_to_book(row['target'])
    # many source-target edges are links within a book;
    # which are good, but generate a self-referential recommendation
    if source_book == target_book:
        continue
    if source_book == chosen_book:
        cnt.update({(target_book, row['source'], row['target'], row['source_centrality'],row['target_centrality']):1} )
results = cnt.most_common(10)
results = sorted(results, key=lambda x:x[0][-1], reverse=True)
print( f"top book recommendations for: {chosen_book}")
results
# Out:
# top book recommendations for: lauret
# [(('fain4',
#    "('lauret', ' about-this-book')",
#    "('fain4', ' chapter-1')",
#    0.02976833206914405,
#    0.017970803170325296),
#   1),
#  (('clinton3',
#    "('lauret', ' chapter-1')",
#    "('clinton3', ' chapter-1')",
#    0.0320760256697409,
#    0.014914561435989222),
#   1),
#  (('hurbans',
#    "('lauret', ' about-this-book')",
#    "('hurbans', ' chapter-1')",
#    0.02976833206914405,
#    0.008724122802748582),
#   1),
#  (('atencio3',
#    "('lauret', ' about-this-book')",
#    "('atencio3', ' chapter-2')",
#    0.02976833206914405,
#    0.006140067858335498),
#   1),
#  (('briggs',
#    "('lauret', ' about-this-book')",
#    "('briggs', ' about-this-book')",
#    0.02976833206914405,
#    0.003249050112318249),
#   1),
#  (('johnsson',
#    "('lauret', ' chapter-3')",
#    "('johnsson', ' chapter-6')",
#    0.010123102660278613,
#    0.000486711651856581),
#   1),
#  (('fain2',
#    "('lauret', 'chapter-11')",
#    "('fain2', 'about-this-book')",
#    5.091126065445408e-07,
#    0.0),
#   1),
#  (('palmer',
#    "('lauret', ' chapter-1')",
#    "('palmer', ' about-this-book')",
#    0.0320760256697409,
#    0.0),
#   1),
#  (('elger',
#    "('lauret', ' chapter-1')",
#    "('elger', ' chapter-1')",
#    0.0320760256697409,
#    0.0),
#   1),
#  (('curcic',
#    "('lauret', ' about-this-book')",
#    "('curcic', ' welcome')",
#    0.02976833206914405,
#    0.0),
#   1)]

# %% [markdown]
# ## Source centrality - measures the quality of the current location in a book
# ## Target centrality - measures the quality of the recommendation, an analog of popularity and recorded importance
